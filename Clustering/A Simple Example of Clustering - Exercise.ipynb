# %% [markdown]
# # A Simple Example of Clustering

# %% [markdown]
# You are given much more country data. Using the same methodology as the one in the lecture, group all the countries in 2 clusters.
#
# Try with other numbers of clusters and see if they match your expectations. Maybe 7 is going to be a cool one!
#
# Plot the data using the <i> c </i> parameter to separate the data by the clusters we defined.
#
# <i> Note: c stands for color <i>

# %% [markdown]
# ## Import the relevant libraries

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set()

from sklearn.cluster import KMeans

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load data from the csv file: <i> 'Countries.csv'</i>.

# %%
df = pd.read_csv( 'Countries.csv')
df.head()
# Out:
#           name  Longitude   Latitude
# 0        Aruba -69.982677  12.520880
# 1  Afghanistan  66.004734  33.835231
# 2       Angola  17.537368 -12.293361
# 3     Anguilla -63.064989  18.223959
# 4      Albania  20.049834  41.142450

# %% [markdown]
# ## Plot the data

# %% [markdown]
# Plot the <i>'Longtitude'</i> and <i>'Latitude'</i> columns.

# %%
plt.scatter(df['Longitude'], df['Latitude'])

# %% [markdown]
# ## Select the features

# %% [markdown]
# Create a copy of that data and remove all parameters apart from <i>Longitude</i> and <i>Latitude</i>.

# %%
x=df.iloc[:,1:3]
x
# Out:
#       Longitude   Latitude
# 0    -69.982677  12.520880
# 1     66.004734  33.835231
# 2     17.537368 -12.293361
# 3    -63.064989  18.223959
# 4     20.049834  41.142450
# ..          ...        ...
# 236 -172.164851 -13.753243
# 237   47.586762  15.909280
# 238   25.083901 -29.000341
# 239   27.774759 -13.458242
# 240   29.851441 -19.004204
#
# [241 rows x 2 columns]

# %% [markdown]
# ## Clustering

# %% [markdown]
# Assume there are only two clusters.

# %%
kmean = KMeans(2)
model = kmean.fit(x)

# %%
kmean3 = KMeans(3)
model3 = kmean3.fit(x)
kmean7 = KMeans(7)
model7 = kmean7.fit(x)

# %% [markdown]
# ### Clustering Resutls

# %%
df['cluster'] = model.fit_predict(x)
df['cluster3'] = model3.fit_predict(x)
df['cluster7'] = model7.fit_predict(x)

# %%
df
# Out:
#              name   Longitude   Latitude  cluster  cluster3  cluster4  \
# 0           Aruba  -69.982677  12.520880        0         1         0
# 1     Afghanistan   66.004734  33.835231        1         2         1
# 2          Angola   17.537368 -12.293361        1         2         1
# 3        Anguilla  -63.064989  18.223959        0         1         0
# 4         Albania   20.049834  41.142450        1         2         1
# ..            ...         ...        ...      ...       ...       ...
# 236         Samoa -172.164851 -13.753243        0         1         0
# 237         Yemen   47.586762  15.909280        1         2         1
# 238  South Africa   25.083901 -29.000341        1         2         1
# 239        Zambia   27.774759 -13.458242        1         2         1
# 240      Zimbabwe   29.851441 -19.004204        1         2         1
#
#      cluster7
# 0           1
# 1           6
# 2           0
# 3           1
# 4           4
# ..        ...
# 236         5
# ...

# %% [markdown]
# Did you remember to use the <i> c </i> parameter to separate the data by the clusters we defined?

# %%
# Two cluster
plt.scatter(df['Longitude'], df['Latitude'], c=df['cluster'], cmap='rainbow')

# %%
# 3 cluster
plt.scatter(df['Longitude'], df['Latitude'], c=df['cluster3'], cmap='rainbow')

# %% [markdown]
# If you haven't, go back and play around with the number of clusters.
#
# Try 3, 7 and 8 and see if the results match your expectations!

# %%
# 7 cluster
plt.scatter(df['Longitude'], df['Latitude'], c=df['cluster7'], cmap='rainbow')
